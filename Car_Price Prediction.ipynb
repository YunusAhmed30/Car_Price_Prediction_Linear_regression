# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('E:\\DataSets\\CarPrice.csv')
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.shape
# Out:
# (205, 26)

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data.loc[data.price==45400]
# Out:
#     car_ID  symboling                          CarName fueltype aspiration  \
# 74      75          1  buick regal sport coupe (turbo)      gas        std
#
#    doornumber  carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 74        two  hardtop        rwd          front      112.0  ...         304
#
#     fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm  \
# 74        mpfi        3.8    3.35              8.0        184     4500
#
#    citympg  highwaympg    price
# 74      14          16  45400.0
#
# [1 rows x 26 columns]

# %%
data.loc[data['car_ID']==205]
# Out:
#      car_ID  symboling      CarName fueltype aspiration doornumber carbody  \
# 204     205         -1  volvo 264gl      gas      turbo       four   sedan
#
#     drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 204        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 204       3.78    3.15              9.5        114     5400      19
#
#      highwaympg    price
# 204          25  22625.0
#
# [1 rows x 26 columns]

# %%
data[data['price']==31600]
# Out:
#     car_ID  symboling        CarName fueltype aspiration doornumber carbody  \
# 70      71         -1  buick skyhawk   diesel      turbo       four   sedan
#
#    drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 70        rwd          front      115.6  ...         183         idi
#
#     boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 70       3.58    3.64             21.5        123     4350      22
#
#     highwaympg    price
# 70          25  31600.0
#
# [1 rows x 26 columns]

# %%
[i for i in data['CarName'] if 'audi' in i]
# Out:
# ['audi 100 ls',
#  'audi 100ls',
#  'audi fox',
#  'audi 100ls',
#  'audi 5000',
#  'audi 4000',
#  'audi 5000s (diesel)']

# %%
data[data['CarName']=='audi 5000s (diesel)']
# Out:
#    car_ID  symboling              CarName fueltype aspiration doornumber  \
# 9      10          0  audi 5000s (diesel)      gas      turbo        two
#
#      carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 9  hatchback        4wd          front       99.5  ...         131
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 9        mpfi       3.13     3.4              7.0        160     5500      16
#
#    highwaympg      price
# 9          22  17859.167
#
# [1 rows x 26 columns]

# %%
data.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
[i for i in data['CarName'] if 'volvo' in i]
# Out:
# ['volvo 145e (sw)',
#  'volvo 144ea',
#  'volvo 244dl',
#  'volvo 245',
#  'volvo 264gl',
#  'volvo diesel',
#  'volvo 145e (sw)',
#  'volvo 144ea',
#  'volvo 244dl',
#  'volvo 246',
#  'volvo 264gl']

# %%
data.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
## There are many spelling mistakes. Let's fix it before proceeding.

data.CarName=data.CarName.str.lower()

def spell_change(previous,now):
    data.CarName.replace(previous,now,inplace=True)
    
spell_change('alfa-romero giulia','alfa-romeo giulia')
spell_change('alfa-romero stelvio','alfa-romeo stelvio')
spell_change('alfa-romero Quadrifoglio','alfa-romeo Quadrifoglio')

spell_change('maxda rx3','mazda rx3')
spell_change('maxda glc deluxe','mazda glc deluxe')


spell_change('porcshce panamera','porsche panamera')
spell_change('toyouta tercel','toyota tercel')

spell_change('vw dasher','volkswagen dasher')
spell_change('vw rabbit','volkswagen rabbit')

# %%
data.CarName.unique()
# Out:
# array(['alfa-romeo giulia', 'alfa-romeo stelvio',
#        'alfa-romero quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu mu-x', 'isuzu d-max ',
#        'isuzu d-max v-cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'mazda rx3', 'mazda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# ## Visualizing the Data

# %%
#Let's visualize the price distribution

plt.rcParams['figure.figsize']=(20,8)
plt.subplot(1,2,1)
sns.distplot(data['price'])
plt.title('Car Price distribution')

plt.subplot(1,2,2)
sns.boxplot(y=data['price'])
plt.title('Price spread ')
# Out:
# Text(0.5, 1.0, 'Price spread ')

# %%
data['price'].describe(percentiles=[0.25,0.5,0.75,0.8,0.9,0.95,1])
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# 80%      17493.800000
# 90%      22563.000000
# 95%      32472.400000
# 100%     45400.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
data[data['price']>25000]
# Out:
#      car_ID  symboling                          CarName fueltype aspiration  \
# 15       16          0                           bmw x4      gas        std
# 16       17          0                           bmw x5      gas        std
# 17       18          0                           bmw x3      gas        std
# 47       48          0                        jaguar xj      gas        std
# 48       49          0                        jaguar xf      gas        std
# 49       50          0                        jaguar xk      gas        std
# 67       68         -1         buick electra 225 custom   diesel      turbo
# 68       69         -1         buick century luxus (sw)   diesel      turbo
# 69       70          0                    buick century   diesel      turbo
# 70       71         -1                    buick skyhawk   diesel      turbo
# 71       72         -1          buick opel isuzu deluxe      gas        std
# ...

# %%
#Here IQR = Q3-Q1= 16503-7788=8715. Hence maximum should be Q3+(1.5*IQR)= 16503+(1.5*8715)=29575.5. Hence, in the box plot,
#the maximum line is showing the value of 29575.5. The others are outliers.

# %%
sns.boxplot(data['price'])

# %%
# From dist plot, we can see that the data is right skewed. It means most of the prices are on the lower side.

# %%
plt.rcParams['figure.figsize']=(20,10)
a=data['CarName'].value_counts()
a.shape
# Out:
# (143,)

# %%
CompanyName=data['CarName'].apply(lambda x:x.split(' ')[0])
CompanyName.value_counts(sort=True)
# Out:
# toyota         32
# nissan         18
# mazda          17
# honda          13
# mitsubishi     13
# subaru         12
# volkswagen     11
# peugeot        11
# volvo          11
# dodge           9
# bmw             8
# buick           8
# plymouth        7
# audi            7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romeo      2
# renault         2
# mercury         1
# alfa-romero     1
# vokswagen       1
# Name: CarName, dtype: int64

# %%
[i for i in data['CarName'] if 'porsche' in i]
# Out:
# ['porsche macan',
#  'porsche panamera',
#  'porsche cayenne',
#  'porsche boxter',
#  'porsche cayenne']

# %%
data.insert(3,'Company',CompanyName)
data.head(2)
# Out:
#    car_ID  symboling             CarName     Company fueltype aspiration  \
# 0       1          3   alfa-romeo giulia  alfa-romeo      gas        std
# 1       2          3  alfa-romeo stelvio  alfa-romeo      gas        std
#
#   doornumber      carbody drivewheel enginelocation  ...  enginesize  \
# 0        two  convertible        rwd          front  ...         130
# 1        two  convertible        rwd          front  ...         130
#
#    fuelsystem  boreratio  stroke  compressionratio horsepower peakrpm  \
# 0        mpfi       3.47    2.68               9.0        111    5000
# 1        mpfi       3.47    2.68               9.0        111    5000
#
#    citympg highwaympg    price
# 0       21         27  13495.0
# 1       21         27  16500.0
#
# [2 rows x 27 columns]

# %%
data.head(2)
# Out:
#    car_ID  symboling             CarName     Company fueltype aspiration  \
# 0       1          3   alfa-romeo giulia  alfa-romeo      gas        std
# 1       2          3  alfa-romeo stelvio  alfa-romeo      gas        std
#
#   doornumber      carbody drivewheel enginelocation  ...  enginesize  \
# 0        two  convertible        rwd          front  ...         130
# 1        two  convertible        rwd          front  ...         130
#
#    fuelsystem  boreratio  stroke  compressionratio horsepower peakrpm  \
# 0        mpfi       3.47    2.68               9.0        111    5000
# 1        mpfi       3.47    2.68               9.0        111    5000
#
#    citympg highwaympg    price
# 0       21         27  13495.0
# 1       21         27  16500.0
#
# [2 rows x 27 columns]

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'Company', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
# Now let's do some visualizations on Company and fueltype

data['Company'].value_counts().plot('bar')
plt.title('Bar Chart on Company level',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Bar Chart on Company level')

# %% [markdown]
# #### We can clearly see that more number of users are preferring Toyota.

# %%
## Alternatively, we can see the visualization with seaborn also.
sns.countplot(data['Company'])

# %%
sns.countplot(data['fueltype'])

# %% [markdown]
# #### We can infer that more number of people are preferring gas fuel than diesel.

# %%
data['aspiration'].value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
sns.countplot(data['aspiration'])

# %% [markdown]
# #### More number of cars are using naturally-aspirated internal combustion engines rather than turbo-aspirated engines.

# %%
data['carbody'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
sns.countplot(data['carbody'])
plt.title('Type of car body',fontsize=30)
# Out:
# Text(0.5, 1.0, 'Type of car body')

# %% [markdown]
# #### We can see that more number of users are preferring Sedan type.

# %%
sns.boxplot(data['carbody'],data['price'])

# %%
data[data['carbody']=='hardtop']
# Out:
#      car_ID  symboling                          CarName  Company fueltype  \
# 69       70          0                    buick century    buick   diesel
# 74       75          1  buick regal sport coupe (turbo)    buick      gas
# 98       99          2                   nissan clipper   nissan      gas
# 126     127          3                 porsche panamera  porsche      gas
# 127     128          3                  porsche cayenne  porsche      gas
# 167     168          2           toyota corona liftback   toyota      gas
# 168     169          2                   toyota corolla   toyota      gas
# 170     171          2                    toyota tercel   toyota      gas
#
#     aspiration doornumber  carbody drivewheel enginelocation  ...  enginesize  \
# 69       turbo        two  hardtop        rwd          front  ...         183
# 74         std        two  hardtop        rwd          front  ...         304
# ...

# %%
data[data['carbody']=='sedan']
# Out:
#      car_ID  symboling          CarName Company fueltype aspiration  \
# 3         4          2      audi 100 ls    audi      gas        std
# 4         5          2       audi 100ls    audi      gas        std
# 5         6          2         audi fox    audi      gas        std
# 6         7          1       audi 100ls    audi      gas        std
# 8         9          1        audi 4000    audi      gas      turbo
# ..      ...        ...              ...     ...      ...        ...
# 200     201         -1  volvo 145e (sw)   volvo      gas        std
# 201     202         -1      volvo 144ea   volvo      gas      turbo
# 202     203         -1      volvo 244dl   volvo      gas        std
# 203     204         -1        volvo 246   volvo   diesel      turbo
# 204     205         -1      volvo 264gl   volvo      gas      turbo
#
#     doornumber carbody drivewheel enginelocation  ...  enginesize  fuelsystem  \
# ...

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'Company', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
data['doornumber'].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
data['drivewheel'].value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
data['enginelocation'].value_counts()
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
# From above, Forward-wheel drive, front-located engines are more preferred.

# %%
sns.boxplot(data['carheight'],data['price'])

# %%
data['symboling'].value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
sns.countplot(data['symboling'])

# %%
sns.boxplot(data['symboling'],data['price'])

# %%
# This is insurance rating. The cars with symboling 0 and 1 are most sold. Price is also less for this symboling (0 & 1).
# -2 symboling cars are less sold. 
# Looks like -1 symboling cars are costly.

# %%
plt.rcParams['figure.figsize']=(20,8)
plt.subplot(1,2,1)
sns.countplot(data['enginetype'])

plt.subplot(1,2,2)
sns.boxplot(x=data['enginetype'],y=data['price'])

df=pd.DataFrame(data.groupby(['enginetype'])['price'].mean().sort_values(ascending=False))
df.plot.bar(figsize=(8,6))
plt.title('Engine type vs Average price')
plt.show()

# %%
# From the above,we can see that "ohc" engine type is most favourable (because it is less in terms of price)
# ohcv is the most costliest one.
# The next favourable can be "ohcf"

# %%
plt.rcParams['figure.figsize']=(12,8)
df=pd.DataFrame(data.groupby('Company')['price'].mean().sort_values(ascending=False))
df.plot.bar()
plt.title('Company vs Average Price')
# Out:
# Text(0.5, 1.0, 'Company vs Average Price')

# %%
# We can see that jaguar is having the highest price whereas chevrolet is having the lowest price

# %%
df=pd.DataFrame(data.groupby('carbody')['price'].mean().sort_values(ascending=False))
df.plot.bar()

# %%
# We can see that hardtop and convertible has highest prices, whereas, hatchback is having lowest price.

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'Company', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
# Now let's visualize numeric data.

# %%
def scatter_plot(x,n):
    plt.subplot(5,2,n)
    plt.scatter(data[x],data['price'])
    plt.title(x+' vs price')
    plt.xlabel(x)
    plt.ylabel('price')
    
plt.rcParams['figure.figsize']=(10,20)

scatter_plot('carlength',1)
scatter_plot('carheight',2)
scatter_plot('carwidth',3)
scatter_plot('curbweight',4)

plt.tight_layout()

# %%
# carlength, carwidth, curbweight are having positive correlation with price; whereas carheight is not having signification relation with price

# %%
data['wheelbase'].value_counts()
# Out:
# 94.5     21
# 93.7     20
# 95.7     13
# 96.5      8
# 98.4      7
# 97.3      7
# 96.3      6
# 107.9     6
# 98.8      6
# 99.1      6
# 104.3     6
# 100.4     6
# 93.1      5
# 97.2      5
# 102.4     5
# 109.1     5
# 95.9      5
# 101.2     4
# 97.0      4
# 114.2     4
# 95.3      4
# 105.8     3
# 103.5     3
# 110.0     3
# 89.5      3
# 99.8      2
# 86.6      2
# 113.0     2
# 104.5     2
# 104.9     2
# 88.6      2
# 96.9      2
# 91.3      2
# 115.6     2
# 102.9     2
# 96.1      2
# 103.3     2
# 112.0     1
# 99.5      1
# 88.4      1
# 99.2      1
# 96.0      1
# 102.0     1
# 106.7     1
# 93.0      1
# 99.4      1
# 93.3      1
# 102.7     1
# 120.9     1
# 95.1      1
# 96.6      1
# 94.3      1
# 108.0     1
# Name: wheelbase, dtype: int64

# %%
def pair_plot(a,b,c):
    sns.pairplot(data,x_vars=[a,b,c],y_vars='price',height=4,aspect=1,kind='scatter')

pair_plot('wheelbase','enginesize','boreratio')
pair_plot('stroke','compressionratio', 'horsepower')
pair_plot('peakrpm','citympg', 'highwaympg')

# %%
# enginesize, boreratio, horsepower, wheelbase - seem to have a significant positive correlation with price.
# citympg and highwaympg has negative correlation with price
# stroke, compressionratio and peakrpm doesn't have much significant relation with price.

# %%
# Let's create fuel economy feature

data['fueleconomy']=(0.55*data['citympg'])+(0.45*data['highwaympg'])

# %%
data['fueleconomy'].value_counts().sort_values()
# Out:
# 22.25     1
# 29.80     1
# 23.00     1
# 34.25     1
# 33.25     1
#          ..
# 21.70     8
# 33.70    10
# 26.70    13
# 21.25    14
# 34.15    16
# Name: fueleconomy, Length: 69, dtype: int64

# %%
# Binning the companies based on prices

data['price']=data['price'].astype('int')
temp=data.copy()
table=temp.groupby(['Company'])['price'].mean()
temp=temp.merge(table.reset_index(),how='left',on='Company')
bins=[0,10000,20000,40000]
cars_bin=['Budget','Medium','Highend']
data['CarRange']=pd.cut(temp['price_y'],bins,right=False,labels=cars_bin)
data.head()
# Out:
#    car_ID  symboling                   CarName      Company fueltype  \
# 0       1          3         alfa-romeo giulia   alfa-romeo      gas
# 1       2          3        alfa-romeo stelvio   alfa-romeo      gas
# 2       3          1  alfa-romero quadrifoglio  alfa-romero      gas
# 3       4          2               audi 100 ls         audi      gas
# 4       5          2                audi 100ls         audi      gas
#
#   aspiration doornumber      carbody drivewheel enginelocation  ...  \
# 0        std        two  convertible        rwd          front  ...
# 1        std        two  convertible        rwd          front  ...
# 2        std        two    hatchback        rwd          front  ...
# 3        std       four        sedan        fwd          front  ...
# 4        std       four        sedan        4wd          front  ...
#
#    boreratio  stroke  compressionratio  horsepower  peakrpm citympg  \
# 0       3.47    2.68               9.0         111     5000      21
# ...

# %%
temp
# Out:
#      car_ID  symboling                   CarName      Company fueltype  \
# 0         1          3         alfa-romeo giulia   alfa-romeo      gas
# 1         2          3        alfa-romeo stelvio   alfa-romeo      gas
# 2         3          1  alfa-romero quadrifoglio  alfa-romero      gas
# 3         4          2               audi 100 ls         audi      gas
# 4         5          2                audi 100ls         audi      gas
# ..      ...        ...                       ...          ...      ...
# 200     201         -1           volvo 145e (sw)        volvo      gas
# 201     202         -1               volvo 144ea        volvo      gas
# 202     203         -1               volvo 244dl        volvo      gas
# 203     204         -1                 volvo 246        volvo   diesel
# 204     205         -1               volvo 264gl        volvo      gas
#
#     aspiration doornumber      carbody drivewheel enginelocation  ...  \
# ...

# %%
# Let's see the correlation between fueleconomy and price

plt.rcParams['figure.figsize']=(8,6)

sns.scatterplot(x=data['fueleconomy'],y=data['price'],hue=data['drivewheel'])

plt.tight_layout()

# %%
# We can see that fuel economy has negative correlation with price which is significant.

# %%
plt.figure(figsize=(25,6))
df=pd.DataFrame(data.groupby(['fuelsystem','drivewheel','CarRange'])['price'].mean().unstack(fill_value=0))
df.plot.bar()
plt.title('CarRange vs Avg Price')
plt.show()

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'Company', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price', 'fueleconomy', 'CarRange'],
#       dtype='object')

# %% [raw]
# Significant variables are :
#
# fueltype
# aspiration
# carbody
# drivewheel
# wheelbase
# carlength
# carwidth
# curbweight
# enginetype
# cylinder number
# enginesize
# Boreratio
# horsepower
# fueleconomy
# CarRange

# %%
data_selected = data[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 
                    'fueleconomy', 'carlength','carwidth', 'CarRange']]
data_selected.head()
# Out:
#    price fueltype aspiration      carbody drivewheel  wheelbase  curbweight  \
# 0  13495      gas        std  convertible        rwd       88.6        2548
# 1  16500      gas        std  convertible        rwd       88.6        2548
# 2  16500      gas        std    hatchback        rwd       94.5        2823
# 3  13950      gas        std        sedan        fwd       99.8        2337
# 4  17450      gas        std        sedan        4wd       99.4        2824
#
#   enginetype cylindernumber  enginesize  boreratio  horsepower  fueleconomy  \
# 0       dohc           four         130       3.47         111        23.70
# 1       dohc           four         130       3.47         111        23.70
# 2       ohcv            six         152       2.68         154        22.15
# 3        ohc           four         109       3.19         102        26.70
# 4        ohc           five         136       3.19         115        19.80
#
#    carlength  carwidth CarRange
# ...

# %%
sns.pairplot(data_selected)

# %% [raw]
# # Out of these features, categorical and non-categorical are:
#
# Categorical:
#
# fueltype
# aspiration
# carbody
# drivewheel
# enginetype
# cylinder number
# CarRange
# -------------
# Non-Categorical:
#
# wheelbase
# carlength
# carwidth
# curbweight
# enginesize
# Boreratio
# horsepower
# fueleconomy

# %%
#Creating dummy variables

def dummies(x,df):
    temp = pd.get_dummies(df[x], drop_first = True)
    df = pd.concat([df, temp], axis = 1)
    df.drop([x], axis = 1, inplace = True)
    return df


data_selected= dummies('fueltype',data_selected)
data_selected= dummies('aspiration',data_selected)
data_selected= dummies('carbody',data_selected)
data_selected= dummies('drivewheel',data_selected)
data_selected= dummies('enginetype',data_selected)
data_selected= dummies('cylindernumber',data_selected)
data_selected= dummies('CarRange',data_selected)

# %%
data_selected.head()
# Out:
#    price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 0  13495       88.6        2548         130       3.47         111
# 1  16500       88.6        2548         130       3.47         111
# 2  16500       94.5        2823         152       2.68         154
# 3  13950       99.8        2337         109       3.19         102
# 4  17450       99.4        2824         136       3.19         115
#
#    fueleconomy  carlength  carwidth  gas  ...  ohcv  rotor  five  four  six  \
# 0        23.70      168.8      64.1    1  ...     0      0     0     1    0
# 1        23.70      168.8      64.1    1  ...     0      0     0     1    0
# 2        22.15      171.2      65.5    1  ...     1      0     0     0    1
# 3        26.70      176.6      66.2    1  ...     0      0     0     1    0
# 4        19.80      176.6      66.4    1  ...     0      0     1     0    0
#
#    three  twelve  two  Medium  Highend
# 0      0       0    0       1        0
# ...

# %%
data_selected.three.value_counts()
# Out:
# 0    204
# 1      1
# Name: three, dtype: int64

# %%
data_selected.shape
# Out:
# (205, 31)

# %%
#Train-test split and scaling

from sklearn.model_selection import train_test_split
df_train,df_test=train_test_split(data_selected,test_size=0.3,random_state=1)

# %%
#Scaling features

from sklearn.preprocessing import MinMaxScaler

scaler=MinMaxScaler()
a=['price','wheelbase','curbweight','enginesize','boreratio','horsepower','fueleconomy','carlength','carwidth']
df_train[a]=scaler.fit_transform(df_train[a])

# %%
df_train.head()
# Out:
#         price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 124  0.188260   0.320690    0.469613    0.335938   0.750000    0.383621
# 181  0.262530   0.617241    0.611135    0.355469   0.521429    0.431034
# 154  0.067230   0.313793    0.245219    0.085938   0.364286    0.025862
# 53   0.037309   0.224138    0.098598    0.082031   0.350000    0.051724
# 94   0.052332   0.272414    0.101147    0.105469   0.435714    0.056034
#
#      fueleconomy  carlength  carwidth  gas  ...  ohcv  rotor  five  four  six  \
# 124     0.176955   0.493103  0.428571    1  ...     0      0     0     1    0
# 181     0.176955   0.744828  0.447619    1  ...     0      0     0     0    1
# 154     0.396433   0.432759  0.171429    1  ...     0      0     0     1    0
# 53      0.530864   0.382759  0.228571    1  ...     0      0     0     1    0
# 94      0.518519   0.356897  0.190476    1  ...     0      0     0     1    0
#
#      three  twelve  two  Medium  Highend
# ...

# %%
df_train.describe()
# Out:
#             price   wheelbase  curbweight  enginesize   boreratio  horsepower  \
# count  143.000000  143.000000  143.000000  143.000000  143.000000  143.000000
# mean     0.208101    0.418881    0.367580    0.228502    0.569730    0.219406
# std      0.200618    0.205394    0.216308    0.161243    0.194399    0.180224
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.063711    0.272414    0.216532    0.109375    0.435714    0.060345
# 50%      0.143017    0.358621    0.317467    0.195312    0.564286    0.176724
# 75%      0.281943    0.537931    0.522949    0.285156    0.742857    0.278017
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#        fueleconomy   carlength    carwidth         gas  ...        ohcv  \
# count   143.000000  143.000000  143.000000  143.000000  ...  143.000000
# mean      0.342772    0.519279    0.402997    0.909091  ...    0.069930
# ...

# %%
df_train.columns
# Out:
# Index(['price', 'wheelbase', 'curbweight', 'enginesize', 'boreratio',
#        'horsepower', 'fueleconomy', 'carlength', 'carwidth', 'gas', 'turbo',
#        'hardtop', 'hatchback', 'sedan', 'wagon', 'fwd', 'rwd', 'dohcv', 'l',
#        'ohc', 'ohcf', 'ohcv', 'rotor', 'five', 'four', 'six', 'three',
#        'twelve', 'two', 'Medium', 'Highend'],
#       dtype='object')

# %%
#Let's check correlation using heatmap

plt.figure(figsize=(30,25))
sns.heatmap(df_train.corr(),annot=True,cmap='PuBu')
plt.show()

# %%
df_train.drop('three',axis=1,inplace=True)

# %%
plt.figure(figsize=(30,25))
sns.heatmap(df_train.corr(),annot=True,cmap='PuBu')
plt.show()

# %%
y_train=df_train.pop('price')
x_train=df_train
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-169-5800150908e2> in <module>
# ----> 1 y_train=df_train.pop('price')
# ...

# %%
#Model building

from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [raw]
# RFE is (Recursive Feature Elimination) feature selection algorithm which is used to select most relevant
# features from the training dataset

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
rfe=RFE(lm,10)

# %%
rfe
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                normalize=False),
#     n_features_to_select=10, step=1, verbose=0)

# %%
rfe=rfe.fit(x_train,y_train)

# %%
list(zip(x_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('wheelbase', False, 3),
#  ('curbweight', True, 1),
#  ('enginesize', False, 8),
#  ('boreratio', True, 1),
#  ('horsepower', True, 1),
#  ('fueleconomy', False, 2),
#  ('carlength', False, 10),
#  ('carwidth', True, 1),
#  ('gas', False, 13),
#  ('turbo', False, 14),
#  ('hardtop', False, 12),
#  ('hatchback', True, 1),
#  ('sedan', True, 1),
#  ('wagon', True, 1),
#  ('fwd', False, 16),
#  ('rwd', False, 18),
#  ('dohcv', True, 1),
#  ('l', False, 17),
#  ('ohc', False, 15),
#  ('ohcf', False, 7),
#  ('ohcv', False, 9),
#  ('rotor', False, 19),
#  ('five', False, 5),
#  ('four', False, 4),
#  ('six', False, 6),
#  ('three', False, 21),
#  ('twelve', True, 1),
#  ('two', False, 20),
#  ('Medium', False, 11),
#  ('Highend', True, 1)]

# %%
x_train.columns[rfe.support_] #It will return the columns which has support as "true"
# Out:
# Index(['curbweight', 'boreratio', 'horsepower', 'carwidth', 'hatchback',
#        'sedan', 'wagon', 'dohcv', 'twelve', 'Highend'],
#       dtype='object')

# %%
x_train_rfe=x_train[x_train.columns[rfe.support_]]
x_train_rfe.head()
# Out:
#      curbweight  boreratio  horsepower  carwidth  hatchback  sedan  wagon  \
# 124    0.469613   0.750000    0.383621  0.428571          1      0      0
# 181    0.611135   0.521429    0.431034  0.447619          0      0      1
# 154    0.245219   0.364286    0.025862  0.171429          0      0      1
# 53     0.098598   0.350000    0.051724  0.228571          0      1      0
# 94     0.101147   0.435714    0.056034  0.190476          0      1      0
#
#      dohcv  twelve  Highend
# 124      0       0        0
# 181      0       0        0
# 154      0       0        0
# 53       0       0        0
# 94       0       0        0

# %%
def model_build(X,y):
    X=sm.add_constant(X)
    lm=sm.OLS(y,X).fit()
    print(lm.summary())
    return X

def checkVIF(X):
    vif=pd.DataFrame()
    vif['Features']=X.columns
    vif['VIF']=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
    vif['VIF']=round(vif['VIF'],2)
    vif=vif.sort_values(by='VIF',ascending=False)
    return(vif)

# %%
#model 1

x_train_new=model_build(x_train_rfe,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                     208.0
# Date:                Wed, 30 Dec 2020   Prob (F-statistic):           1.15e-75
# Time:                        20:35:41   Log-Likelihood:                 228.84
# No. Observations:                 143   AIC:                            -435.7
# Df Residuals:                     132   BIC:                            -403.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0720      0.024      2.955      0.004       0.024       0.120
# ...

# %%
checkVIF(x_train_new)
# Out:
#       Features    VIF
# 0        const  32.89
# 1   curbweight   6.88
# 6        sedan   5.26
# 5    hatchback   4.80
# 4     carwidth   4.12
# 3   horsepower   3.75
# 7        wagon   3.40
# 10     Highend   1.70
# 2    boreratio   1.65
# 8        dohcv   1.42
# 9       twelve   1.19

# %%
#dropping curbweight because of high VIF value. (shows that curbweight has high multicollinearity.)

# %%
x_train_new=x_train_new.drop(['curbweight'],axis=1)

# %%
x_train_new.head()
# Out:
#      const  boreratio  horsepower  carwidth  hatchback  sedan  wagon  dohcv  \
# 124    1.0   0.750000    0.383621  0.428571          1      0      0      0
# 181    1.0   0.521429    0.431034  0.447619          0      0      1      0
# 154    1.0   0.364286    0.025862  0.171429          0      0      1      0
# 53     1.0   0.350000    0.051724  0.228571          0      1      0      0
# 94     1.0   0.435714    0.056034  0.190476          0      1      0      0
#
#      twelve  Highend
# 124       0        0
# 181       0        0
# 154       0        0
# 53        0        0
# 94        0        0

# %%
#Model 2
x_train_new=model_build(x_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.929
# Method:                 Least Squares   F-statistic:                     206.5
# Date:                Wed, 30 Dec 2020   Prob (F-statistic):           1.25e-73
# Time:                        20:40:32   Log-Likelihood:                 220.81
# No. Observations:                 143   AIC:                            -421.6
# Df Residuals:                     133   BIC:                            -392.0
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0592      0.025      2.324      0.022       0.009       0.110
# ...

# %%
#p-vale of boreratio seems to be higher than the significance value of 0.05, 
#hence dropping it as it is insignificant in presence of other variables.

# %%
x_train_new=x_train_new.drop(['boreratio'],axis=1)

# %%
x_train_new.head()
# Out:
#      const  horsepower  carwidth  hatchback  sedan  wagon  dohcv  twelve  \
# 124    1.0    0.383621  0.428571          1      0      0      0       0
# 181    1.0    0.431034  0.447619          0      0      1      0       0
# 154    1.0    0.025862  0.171429          0      0      1      0       0
# 53     1.0    0.051724  0.228571          0      1      0      0       0
# 94     1.0    0.056034  0.190476          0      1      0      0       0
#
#      Highend
# 124        0
# 181        0
# 154        0
# 53         0
# 94         0

# %%
#Model 3
x_train_new=model_build(x_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.928
# Method:                 Least Squares   F-statistic:                     228.1
# Date:                Wed, 30 Dec 2020   Prob (F-statistic):           3.94e-74
# Time:                        20:43:25   Log-Likelihood:                 219.09
# No. Observations:                 143   AIC:                            -420.2
# Df Residuals:                     134   BIC:                            -393.5
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0339      0.021      1.583      0.116      -0.008       0.076
# ...

# %%
#p-vale of twelve seems to be higher than the significance value of 0.05,
#hence dropping it as it is insignificant in presence of other variables.

# %%
x_train_new=x_train_new.drop(['twelve'],axis=1)

# %%
#Model 4
x_train_new=model_build(x_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     256.0
# Date:                Wed, 30 Dec 2020   Prob (F-statistic):           1.17e-74
# Time:                        20:44:18   Log-Likelihood:                 217.39
# No. Observations:                 143   AIC:                            -418.8
# Df Residuals:                     135   BIC:                            -395.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0421      0.021      1.994      0.048       0.000       0.084
# ...

# %%
checkVIF(x_train_new)
# Out:
#      Features    VIF
# 0       const  21.48
# 4       sedan   4.98
# 3   hatchback   4.55
# 5       wagon   3.06
# 1  horsepower   2.39
# 2    carwidth   1.81
# 7     Highend   1.65
# 6       dohcv   1.20

# %%
# Residual analysis

lm=sm.OLS(y_train,x_train_new).fit()
y_train_price=lm.predict(x_train_new)

# %%
y_train_price.head()
# Out:
# 124    0.225083
# 181    0.270805
# 154    0.018691
# 53     0.054902
# 94     0.042532
# dtype: float64

# %%
#plotting the histogram of error terms

fig=plt.figure()
sns.distplot((y_train-y_train_price),bins=20)
fig.suptitle('Error terms',fontsize=30)
plt.xlabel('Errors')
# Out:
# Text(0.5, 0, 'Errors')

# %%
#Error terms seem to be approximately normally distributed, so the assumption on the linear modeling seems to be fulfilled.

# %%
#Scaling the test set

num_vars = ['wheelbase', 'curbweight', 'enginesize', 'boreratio', 'horsepower','fueleconomy','carlength','carwidth','price']
df_test[num_vars]=scaler.fit_transform(df_test[num_vars])

# %%
df_test.head()
# Out:
#         price  wheelbase  curbweight  enginesize  boreratio  horsepower  \
# 78   0.042849   0.206997    0.200155    0.125506   0.067416    0.147059
# 97   0.079592   0.230321    0.212956    0.145749   0.269663    0.154412
# 151  0.033704   0.265306    0.214119    0.125506   0.157303    0.102941
# 44   0.104926   0.230321    0.149728    0.117409   0.134831    0.161765
# 40   0.143023   0.288630    0.342901    0.198381   0.269663    0.279412
#
#      fueleconomy  carlength  carwidth  gas  ...  ohcv  rotor  five  four  six  \
# 78      0.553161   0.241791  0.359649    1  ...     0      0     0     1    0
# 97      0.540230   0.434328  0.307018    1  ...     0      0     0     1    0
# 151     0.553161   0.262687  0.289474    1  ...     0      0     0     1    0
# 44      0.728448   0.220896  0.289474    1  ...     0      0     0     1    0
# 40      0.425287   0.511940  0.192982    1  ...     0      0     0     1    0
#
#      three  twelve  two  Medium  Highend
# ...

# %%
#Splitting

y_test=df_test.pop('price')
x_test=df_test

# %%
x_train_new.head()
# Out:
#      const  horsepower  carwidth  hatchback  sedan  wagon  dohcv  Highend
# 124    1.0    0.383621  0.428571          1      0      0      0        0
# 181    1.0    0.431034  0.447619          0      0      1      0        0
# 154    1.0    0.025862  0.171429          0      0      1      0        0
# 53     1.0    0.051724  0.228571          0      1      0      0        0
# 94     1.0    0.056034  0.190476          0      1      0      0        0

# %%
x_test.head()
# Out:
#      wheelbase  curbweight  enginesize  boreratio  horsepower  fueleconomy  \
# 78    0.206997    0.200155    0.125506   0.067416    0.147059     0.553161
# 97    0.230321    0.212956    0.145749   0.269663    0.154412     0.540230
# 151   0.265306    0.214119    0.125506   0.157303    0.102941     0.553161
# 44    0.230321    0.149728    0.117409   0.134831    0.161765     0.728448
# 40    0.288630    0.342901    0.198381   0.269663    0.279412     0.425287
#
#      carlength  carwidth  gas  turbo  ...  ohcv  rotor  five  four  six  \
# 78    0.241791  0.359649    1      0  ...     0      0     0     1    0
# 97    0.434328  0.307018    1      0  ...     0      0     0     1    0
# 151   0.262687  0.289474    1      0  ...     0      0     0     1    0
# 44    0.220896  0.289474    1      0  ...     0      0     0     1    0
# 40    0.511940  0.192982    1      0  ...     0      0     0     1    0
#
#      three  twelve  two  Medium  Highend
# ...

# %%
x_train_new=x_train_new.drop('const',axis=1)
x_test_new=x_test[x_train_new.columns]
x_test_new=sm.add_constant(x_test_new)

# %%
x_test_new.head()
# Out:
#      const  horsepower  carwidth  hatchback  sedan  wagon  dohcv  Highend
# 78     1.0    0.147059  0.359649          1      0      0      0        0
# 97     1.0    0.154412  0.307018          0      0      1      0        0
# 151    1.0    0.102941  0.289474          1      0      0      0        0
# 44     1.0    0.161765  0.289474          0      1      0      0        0
# 40     1.0    0.279412  0.192982          0      1      0      0        0

# %%
#Let's see the prediction

y_pred=lm.predict(x_test_new)

# %%
y_pred
# Out:
# 78     0.111756
# 97     0.116273
# 151    0.069593
# 44     0.118198
# 40     0.126589
#          ...
# 39     0.213469
# 110    0.335443
# 164    0.104358
# 56     0.243897
# 176    0.271720
# Length: 62, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7668362268093281

# %%
#Let's see the spread

fig=plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test VS y_pred')
plt.xlabel('y_test')
plt.ylabel('y_pred')
# Out:
# Text(0, 0.5, 'y_pred')

# %%
y_test
# Out:
# 78     0.042849
# 97     0.079592
# 151    0.033704
# 44     0.104926
# 40     0.143023
#          ...
# 39     0.102964
# 110    0.241512
# 164    0.086195
# 56     0.185844
# 176    0.159682
# Name: price, Length: 62, dtype: float64

# %%
y_pred
# Out:
# 78     0.111756
# 97     0.116273
# 151    0.069593
# 44     0.118198
# 40     0.126589
#          ...
# 39     0.213469
# 110    0.335443
# 164    0.104358
# 56     0.243897
# 176    0.271720
# Length: 62, dtype: float64

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.926
# Method:                 Least Squares   F-statistic:                     256.0
# Date:                Thu, 31 Dec 2020   Prob (F-statistic):           1.17e-74
# Time:                        20:11:22   Log-Likelihood:                 217.39
# No. Observations:                 143   AIC:                            -418.8
# Df Residuals:                     135   BIC:                            -395.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0421      0.021      1.994      0.048       0.000       0.084
# ...

# %% [raw]
# 1. R-sqaured and Adjusted R-squared (extent of fit) -> 0.930 and 0.926 - 90% variance explained.
#
# 2. F-stats and Prob(F-stats) (overall model fit) -> 256.0 and 1.17e-74(approx. 0.0) -> Model fit is significant and explained 90% variance is just not by chance.
# 3. p-values for all the coefficients seem to be less than the significance level of 0.05. - meaning that all the predictors are statistically significant.
